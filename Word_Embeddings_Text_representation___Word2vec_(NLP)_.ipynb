# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmad-AI7/Word-Embeddings-Text-representation-_-Word2vec-NLP-/blob/main/Word_Embeddings_Text_representation___Word2vec_(NLP)_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import gensim
import os

# %%
# !pip install --upgrade gensim --user

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import os
import nltk
nltk.download('punkt_tab')

story = []
# Assuming '001ssb.txt' is a file, read its content directly
with open('/content/001ssb.txt', 'r') as f:
    corpus = f.read()
# Process the corpus as before
raw_sent = sent_tokenize(corpus)
for sent in raw_sent:
    story.append(simple_preprocess(sent))
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
story
# Out:
# [['game',
#   'of',
#   'thrones',
#   'book',
#   'one',
#   'of',
#   'song',
#   'of',
#   'ice',
#   'and',
#   'fire',
#   'by',
#   'george',
#   'martin',
#   'prologue',
#   'we',
#   'should',
#   'start',
#   'back',
#   'gared',
#   'urged',
#   'as',
#   'the',
#   'woods',
#   'began',
#   'to',
#   'grow',
#   'dark',
#   'around',
#   'them'],
#  ['the', 'wildlings', 'are', 'dead'],
#  ['do', 'the', 'dead', 'frighten', 'you'],
#  ['ser',
#   'waymar',
#   'royce',
#   'asked',
#   'with',
#   'just',
#   'the',
#   'hint',
#   'of',
#   'smile'],
#  ['gared', 'did', 'not', 'rise', 'to', 'the', 'bait'],
#  ['he',
#   'was',
#   'an',
#   'old',
#   'man',
#   'past',
#   'fifty',
#   'and',
#   'he',
#   'had',
#   'seen',
#   'the',
#   'lordlings',
#   'come',
#   'and',
#   'go'],
#  ['dead', 'is', 'dead', 'he', 'said'],
#  ['we', 'have', 'no', 'business', 'with', 'the', 'dead'],
#  ['are', 'they', 'dead'],
#  ['royce', 'asked', 'softly'],
# ...

# %%
model = gensim.models.Word2Vec(
    window=10,
    min_count=2
)

# %%
model.build_vocab(story)

# %%
model.train(story, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (1058286, 1423500)

# %%
model.wv.most_similar('hound')
# Out:
# [('marillion', 0.9960961937904358),
#  ('tomard', 0.9958276748657227),
#  ('daenerys', 0.9957854151725769),
#  ('wine', 0.9955428838729858),
#  ('singer', 0.9950287342071533),
#  ('mycah', 0.9948473572731018),
#  ('smiling', 0.9946773648262024),
#  ('squire', 0.994638979434967),
#  ('animal', 0.9942787885665894),
#  ('pup', 0.9942289590835571)]

# %%
model.wv.most_similar('prince')
# Out:
# [('reminded', 0.9938733577728271),
#  ('uncle', 0.9919286370277405),
#  ('lad', 0.9901977777481079),
#  ('murmured', 0.9901592135429382),
#  ('laugh', 0.9897393584251404),
#  ('summoned', 0.9892217516899109),
#  ('grief', 0.9889535903930664),
#  ('vayon', 0.9889167547225952),
#  ('birthing', 0.9887068867683411),
#  ('sick', 0.9884890913963318)]

# %%
model.wv.similarity('arya' , 'sansa')
# Out:
# 0.9767776

# %%
model.wv['deep'].shape
# Out:
# (100,)

# %%
vec = model.wv.get_normed_vectors()

# %%
vec
# Out:
# array([[-0.00537714,  0.05108757, -0.00638249, ..., -0.13877103,
#          0.00414727,  0.11062601],
#        [-0.00302348,  0.11071271, -0.04767117, ..., -0.16113159,
#          0.03691628,  0.02277291],
#        [-0.17244844,  0.0314271 ,  0.01187467, ..., -0.04030837,
#          0.07034095, -0.13890067],
#        ...,
#        [-0.05479832, -0.02784831,  0.00413128, ..., -0.15796733,
#          0.0426545 , -0.04917226],
#        [-0.00260855,  0.06705839, -0.03050004, ..., -0.15811165,
#         -0.0028763 , -0.03400472],
#        [ 0.01187008,  0.13741091, -0.05218569, ..., -0.16519368,
#          0.03254907, -0.03853969]], dtype=float32)

# %%
vec = model.wv.get_normed_vectors()

# %%
vec.shape
# Out:
# (7432, 100)

# %%
# !pip install matplotlib plotly scikit-learn --upgrade --user
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)
result = pca.fit_transform(vec)

fig = px.scatter_3d(
    result, x=0, y=1, z=2,
    color=model.wv.index_to_key # word labels
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
